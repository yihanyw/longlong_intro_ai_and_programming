# %% [markdown]
# # Small Projects

# %% [markdown]
# ## 1. Cakes Store Analysis
#
# A cake store records sales data.
#
# You are given:
# - a list of cake flavors sold
# - a list of shifts when each cake was sold ("AM" or "PM")

# %%
cake_flavor_sold =  ['Vanilla', 'Chocolate',    'Red Velvet',   'Carrot',   'Lemon',    'Strawberry',   'Cookie',   'Mocha',    'Apple',    'Cookie',   'Mocha',    'Apple',    "Vanilla"]
cake_shift_sold =   ['AM',      'PM',           'PM',           'PM',       'AM',       'AM',           'PM',       "AM",       "PM",       'AM',       "PM",       "PM",       "AM"]

# %% [markdown]
# #### Function 1: Count Cakes Sold by Shift
# Create a function that counts how many cakes were sold in each shift.
# * Input: a list of shifts (e.g. ["AM", "PM", "AM"])
# * Use a loop to go through the list
# * Use if/else to check each value
# * Count:
#     * AM sales
#     * PM sales
# * Return result as a list: [am_count, pm_count]

# %% [markdown]
# #### Function 2: Get Unique Cake Flavors
#
# * Find all unique cake flavors sold.
# * Input: a list of cake flavors
# * Create an empty list for unique flavors
# * Loop through all flavors
# * If a flavor is NOT already in the unique list, add it
# * Return the unique list

# %% [markdown]
# ## 2. Birthday tracker
#
# You will build a program that:
# - stores names + birthdays (in the format: mm-dd-yyyy)
# - lets user add, search, delete, and view all contacts
# - keeps running until user quits
#
# We will use:
# - dictionaries
# - loops
# - if/elif statements
# - input/output
# ```
# birthdays = {
#     "Alice": "03-12-2009",
#     "Bob": "11-05-2008"
# }
# ```
# 1. create your container - dictionary
# 2. create a main loop (continue looping)
# 3. create a menue (print out the avaiable selections)
# 4. user selects an option
# 5. handle each option (if user slected this, do something)
#     - `add contact` - ask for name, ask for birthday, store in dictionary
#     - `search contact` - ask for name, check if it exists, shows result or error message
#     - `delete contact` - ask for name, check if it exists, delete it
#     - `show all contacts` - loop through dictionary, print each item
#     - `quit program` - end the program by break
#
# ```
# Create dictionary
#
# LOOP forever:
#     print menu
#     get user choice
#
#     IF add:
#         store data
#
#     IF search:
#         find data
#
#     IF delete:
#         remove data
#
#     IF show all:
#         display dictionary
#
#     IF quit:
#         stop loop
# END
# ```

# %% [markdown]
# ## 3. Mini Contact Book
# You will build a program that can:
# - add contacts
# - search contacts
# - delete contacts
# - show all contacts
#
# But this time, each feature is a function.<br>
# Instead of writing everything inside one loop, you split logic like:
# - add_contact()
# - search_contact()
# - delete_contact()
# - show_contacts()
#
# Create a contact for yourself at the start (make up the information!). In delete_contact(), prevent the user from deleting your own contact.
#
#
# ```
# Create dictionary
#
# LOOP forever:
#     print menu
#     get user choice
#
#     IF add:
#         call add_contact()
#
#     IF search:
#         call search_contact()
#
#     IF delete:
#         call delete_contact()
#
#     IF show all:
#         call delete_contact()
#
#     IF quit:
#         stop loop
# END
# ```

# %% [markdown]
# ### Exercise, make the Mini Contact Book functions into a module
