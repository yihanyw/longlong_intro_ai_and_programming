# %%
# Cell 1: Visuals for the game
HANGMAN_STAGES = [
    """
       --------
       |      |
       |      
       |    
       |      
       |     
    - - - - - -
    """,
    """
       --------
       |      |
       |      O
       |    
       |      
       |     
    - - - - - -
    """,
    """
       --------
       |      |
       |      O
       |      |
       |      
       |     
    - - - - - -
    """,
    """
       --------
       |      |
       |      O
       |     /|
       |      
       |     
    - - - - - -
    """,
    """
       --------
       |      |
       |      O
       |     /|\\
       |      
       |     
    - - - - - -
    """,
    """
       --------
       |      |
       |      O
       |     /|\\
       |     / 
       |     
    - - - - - -
    """,
    """
       --------
       |      |
       |      O
       |     /|\\
       |     / \\
       |     
    - - - - - -
    """
]

# %%
# Cell 2: Game Logic
import random
from IPython.display import clear_output
import sys

def play_hangman():
    # 1. Word pool (feel free to change the words)
    # word_pool : a list of words to use
    # secret_word : randomly select a word
    # word_set : create a set of the characters in secret_word


    # 2. Game state variables
    # guessed_letters : an empty set to store the guessed characters
    # wrong_guesses =0, int variable to store the number of wrong guesses
    # max_wrong_guesses = 6, max number of possible wrong guesses
    
    print("Welcome to Hangman! Let's begin.")
    
    # 3. Main Game Loop
    while wrong_guesses < max_wrong_guesses:
        # Clear previous outputs to keep the notebook clean
        clear_output(wait=True)
        
        # Display the current gallows stage
        print(HANGMAN_STAGES[wrong_guesses])
        
        # Display the hidden word (e.g., p _ t h _ _ )
        # the guessed letters so far
        # remaining lives
            
        # Get player input
        guess = input("Guess a letter: ").lower().strip()
        
        # Validate input
            
        # if the letter was already guessed
        
        # Check if guess is wrong

        # Add guess to the set

        # check if the player guessed all the unique charactesr of the word
        # if so, break from the loop
            
    else:
        # This executes if the while loop finishes without a 'break' (Player lost)

# %%
# Call the function to start the game
